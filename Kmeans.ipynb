# %% [markdown]
# <a href="https://colab.research.google.com/github/Dp4150/Machine-Learning/blob/main/Kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
#loading the dataset
df1=pd.read_excel("/content/kmean.xlsx",sheet_name="kmeans_data",header=None)
df1
# Out:
#             0         1
# 0    1.842080  4.607572
# 1    5.658583  4.799964
# 2    6.352579  3.290854
# 3    2.904017  4.612204
# 4    3.231979  4.939894
# ..        ...       ...
# 295  7.302787  3.380160
# 296  6.991984  2.987067
# 297  4.825534  2.779617
# 298  6.117681  2.854757
# 299  0.940489  5.715568
#
# [300 rows x 2 columns]

# %%
#centroids of the clusters -> number the clusters
#define numbers=3
import random
init_centroid=random.sample(range(0,len(df1)),3)
init_centroid
# Out:
# [257, 85, 272]

# %%
#identified our centroids to the clusters
centroids=[]
for i in init_centroid:
  centroids.append(df1.iloc[i])
centroids
# Out:
# [0    6.407739
#  1    2.675550
#  Name: 257, dtype: float64,
#  0    2.403047
#  1    5.081473
#  Name: 85, dtype: float64,
#  0    6.885756
#  1    2.888453
#  Name: 272, dtype: float64]

# %%
centroids=np.array(centroids)
centroids
# Out:
# array([[6.40773863, 2.67554951],
#        [2.40304747, 5.08147326],
#        [6.88575584, 2.88845269]])

# %%
x=np.array(df1)

# %%
#Euclidean distance formula
def calc_distance(i,j):
  return(sum((i-j)**2))**0.5

# %%
#for any given datapoint, find out the nearest centroid
def findnearcentroid(centroid,x):
  assignedcluster=[]
  for i in x:
    dist=[]
    for j in centroid:
      dist.append(calc_distance(i,j))
      assignedcluster.append(np.argmin(dist))
      return assignedcluster

# %%
get_centroid=findnearcentroid(centroids,x)
get_centroid
# Out:
# [0]

# %%
#getting the new centroid
def calculating_centroid(cluster_number,x):
  new_centroid=[]
  new_df=pd.concat([pd.DataFrame(x),pd.DataFrame(cluster_number,columns=['cluster'])],axis=1)
  for c in set(new_df['cluster']):  #c->0,1,2
    current_cluster=new_df[new_df['cluster']==c][new_df.columns[:-1]]
    cluster_mean=current_cluster.mean(axis=0)
    new_centroid.append(cluster_mean)
  return new_centroid

# %%
epochs=10
for i in range(epochs):
  get_centroid=findnearcentroid(centroids,x)
  centroids=calculating_centroid(get_centroid,x)
  plt.figure()
  plt.scatter(np.array(centroids)[:,0],np.array(centroids)[:,1],color='black')    #ploting the scateer plot
  plt.scatter(x[:,0],x[:,1],alpha=0.3)     #plotting the observation points
  plt.show()

# %%
print(np.array(centroids))
# Out:
# [[1.84207953 4.6075716 ]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]
#  [       nan        nan]]
